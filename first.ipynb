# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('train.csv')

# %%
x={'male':1,'female':2}

# %%
plt.figure()

# %%
xd=df[(df["Pclass"]==3)]

# %%
df['Age'].count()
# Out:
# 714

# %%
x={'male':1,'female':2}

# %%
df['Sex']=df['Sex'].str.strip().map(x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-464998aed36d> in <module>()
# ----> 1 df['Sex']=df['Sex'].str.strip().map(x)
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4366         if (name in self._internal_names_set or name in self._metadata or
#    4367                 name in self._accessors):
# -> 4368             return object.__getattribute__(self, name)
#    4369         else:
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     131             # we're accessing the attribute of the class, i.e., Dataset.geo
#     132             return self._accessor
# --> 133         accessor_obj = self._accessor(obj)
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
x={'male':1,'female':2}

# %%
df.drop(['Name'],axis=1,inplace=True)

# %%
df.drop(['Sex'],axis=1,inplace=True)
